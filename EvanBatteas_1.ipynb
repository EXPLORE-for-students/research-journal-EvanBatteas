# %% [markdown]
# # Research Notebook
# ## Evan Batteas
# ## Date: 02/10/2025

# %% [markdown]
# # 1: Experience
# ## Describe at least one research activity you worked on this week.
#
# I've worked on getting into the COSMA supercomputing system and setting up my python environment, as well as adding the starter code provdided to use to our environment
#
# ## Motivation:
#
# We want to familiarize ourself with access the data from the COCO WDM simulations.

# %% [markdown]
# # 2: What? (What happened?)
# ## Describe what happened during your activities for the week.
#
# I ran into several errors while trying to set everything up.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## Describe your results
#
# It was interesting to see the spatial distribution of the subhalos.

# %% [markdown]
# # 4. Now what? (What's next?)
# ## Plan for the next week
#
# For next week, I plan to improve my cuts to find a MW and M31 pair, for example, implementing isolation cuts, and making sure that they are moving towards each other. Then, maybe I can try using the timing argument to estimate the mass of the local group, with the equations $v = (\frac{2GM_{total}}{R_{max}})^{1/2}(\frac{sin(\theta)}{1-cos(theta)})$ and $\frac{vt}{r} = \frac{sin(\theta)(\theta - sin(\theta))}{(1-cos(\theta)^2)}$

# %% [markdown]
# # 5. Bibliography
#
# Institute for Computational Cosmology, Local Group timing argument, https://icc.dur.ac.uk/~tt/Lectures/Galaxies/TeX/lec/node54.html
