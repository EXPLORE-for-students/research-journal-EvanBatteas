# %% [markdown]
# # Research Notebook
# ## Evan Batteas
# ## Date: 03/04/2025

# %% [markdown]
# # 1: Experience
# ## Describe at least one research activity you worked on this week.
#
# In the last week I worked on running through the timing argument simulations for each MW M31 analogue I found.
#
# ## Motivation:
#
# The motivation for doing this is to find the mass of the local group by tweaking the intial mass parameter and evolving it through runge-kutta 4th order kinematic simualtion.

# %% [markdown]
# # 2: What? (What happened?)
# ## Describe what happened during your activities for the week.
#
# I found masses of the LG for each of the analogue pairs. I iterated through the intial mass for each pair, and found the mass for which their initial separation was the smallest. I repeated this for all of the pairs.

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## Describe your results
#
# All of the masses from the timing argument were larger than the masses we found in the COCO simulation, which means the timing argument has a bias towards spiiting our larger masses. As well as this, some of the pairs did not reach a very small intial separation, one was even as high as a few hundred kpc. This means that the timing argument does not work as well with them as it does with those pairs that got to a much smaller initial separation. Now, we have our result that we were searching for, the mass of the LG, and we have 6 samples to do statistics with.
#
# Example trajectory 1:
# ![image.png](attachment:image.png)
#
# Example trajectory 2:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 4. Now what? (What's next?)
# ## Plan for the next week
#
# Summarize and interpret the results that we found, and discuss with each other. If we have time, we can compare the results with what we would get if we used cold dark matter instead of warm.

# %% [markdown]
# # 5. Bibliography
#
# Your references here
